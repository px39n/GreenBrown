# %%
import numpy as np
import matplotlib.pyplot as plt
from greenbrown.utils import *
import greenbrown as gb

# %%
import os 
os.path.isdir(".\\data")
# Out:
# True

# %%
Yt = load_example()
Tt = Yt.index

bst=gb.bfast.BFAST(Yt,Tt,max_iter=1)
bst.plot()
bst.summary()
yt,tt,st,rt=bst.composition
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-8f95d3839ce1> in <module>
# ----> 1 Yt = load_example()
#       2 Tt = Yt.index
#       3
#       4 bst=gb.bfast.BFAST(Yt,Tt,max_iter=1)
#       5 bst.plot()
#
# D:\Code\GreenBrown\greenbrown\utils.py in load_example()
#      63     save = "\\data\\time_series.csv"
#      64
# ---> 65     ndvi_d = pd.read_csv(save)
#      66     ndvi_date = pd.to_datetime(ndvi_d["time"], format="%Y-%m-%d")
#      67     value = ndvi_d.values[:, 1].astype("float32")
#
# D:\ProgramData\Anaconda3\envs\tf\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# D:\ProgramData\Anaconda3\envs\tf\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# D:\ProgramData\Anaconda3\envs\tf\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# D:\ProgramData\Anaconda3\envs\tf\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# D:\ProgramData\Anaconda3\envs\tf\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\data\\time_series.csv'

# %%
trd=gb.TrendAAT(Yt,Tt,0.15,0.05)
trd.summary()
trd.plot()
ATs,Am,An=trd.values
# Out:
# --- Trend ---------------------------------------------------------
# Calculate Annual Aggravated trends and trend changes on time series
# -------------------------------------------------------------------
#
# Table1. Time Series Information:
# +---------------------+---------------------+
# |         Name        |         Time        |
# +---------------------+---------------------+
# |  Time series start: | 2009-05-31 00:00:00 |
# |   Time series end:  | 2016-09-30 00:00:00 |
# | Time series length: |          89         |
# +---------------------+---------------------+
# Table2. Test for Structural change
#
# +--------------+-------------------------------+
# |     Name     |             Value             |
# +--------------+-------------------------------+
# |   Method:    |      OLS-based MOSUM test     |
# |  Statistic:  |       0.5435914898958671      |
# |   P-value:   |       0.563614003294728       |
# | Breakpoints: | Breakpoints were not detected |
# +--------------+-------------------------------+
# Table3. Trend in segments of the time series
#
# +-----------------------------+---------------------+
# |             Name            |        Value        |
# +-----------------------------+---------------------+
# |           Method:           |       MK Test       |
# |            Trend:           |       no trend      |
# |           P-value:          |  0.536186771900174  |
# | Normalized test statistics: |  0.6185895741317419 |
# |         MK's score:         |         6.0         |
# |         Kendall Tau:        | 0.21428571428571427 |
# |         Variance s:         |  65.33333333333333  |
# |            Slope:           |  0.1350342333316803 |
# |          Intercept:         | 0.05901952087879181 |
# +-----------------------------+---------------------+

# %%
trd2=gb.TrendSST(Yt,Tt)
trd2.summary()
trd2.plot()
STs,St_bp=trd2.values
# Out:
# The 1st iter of 3
# The 2st iter of 3
# The 3st iter of 3
# --- Trend ---------------------------------------------------------
# Calculate Seasonal composition and trend changes on time series
# -------------------------------------------------------------------
#
# Table1. Time Series Information:
# +---------------------+---------------------+
# |         Name        |         Time        |
# +---------------------+---------------------+
# |  Time series start: | 2009-05-31 00:00:00 |
# |   Time series end:  | 2016-09-30 00:00:00 |
# | Time series length: |          89         |
# +---------------------+---------------------+
# Table2. Test for Structural change
#
# +--------------+----------------------+
# |     Name     |        Value         |
# +--------------+----------------------+
# |   Method:    | OLS-based MOSUM test |
# |  Statistic:  |  0.9135476488409051  |
# |   P-value:   |  0.2666194951772236  |
# | Breakpoints: |      [-1 52 87]      |
# +--------------+----------------------+
# Table3. Trend in segments of the time series
#
# +-----------------------------+-----------------------+
# |             Name            |         Value         |
# +-----------------------------+-----------------------+
# |           Method:           |        MK Test        |
# |            Trend:           |        no trend       |
# |           P-value:          |   0.980206920178549   |
# | Normalized test statistics: |  0.024809491611587714 |
# |         MK's score:         |          8.0          |
# |         Kendall Tau:        | 0.0020429009193054137 |
# |         Variance s:         |   79608.66666666667   |
# |            Slope:           |          0.0          |
# |          Intercept:         |          0.0          |
# +-----------------------------+-----------------------+

# %%
trd3=gb.AnomalyDetection(Yt,Tt)
trd3.summary()
trd3.plot()
ATs,Am,An,Sts,St_bp,Rem=trd3.values
# Out:
# D:\Code\GreenBrown\greenbrown\bfast\mosum.py:127: RuntimeWarning: All-NaN axis encountered
#   min=np.nanmin(break_rss)
# --- Trend ---------------------------------------------------------
# This Part is Unfinished. Will be added in next Version
# ----------------------------------------------a---------------------

# %%
tif = load_tif_sample()[20:24,20:24,:]
tif_index = pd.date_range('2000', periods=16, freq='Y')
tif = interpolate_3d(tif)
Ss = gb.Spatial_Statistcs(tif,tif_index)
Ss.excute()
Ss.plot()
Ss.summary()
# Out:
# The 0,0st iter of 4,4
# The 0,1st iter of 4,4
# The 0,2st iter of 4,4
# The 0,3st iter of 4,4
# The 1,0st iter of 4,4
# The 1,1st iter of 4,4
# The 1,2st iter of 4,4
# The 1,3st iter of 4,4
# The 2,0st iter of 4,4
# The 2,1st iter of 4,4
# The 2,2st iter of 4,4
# The 2,3st iter of 4,4
# The 3,0st iter of 4,4
# The 3,1st iter of 4,4
# The 3,2st iter of 4,4
# The 3,3st iter of 4,4

# %%
# Out:
# array([1, 2, 3, 4])
